# %%
staging_path = dbutils.jobs.taskValues.get(taskKey="notebook_1", key="staging_path")
output_path  = "/Volumes/emission/default/emissions_volume/output/emissions_dashboard"

# %% [markdown]
# Reading parquet from emission_ingestion_clean

# %%
df = spark.read.parquet(staging_path)

print(f"Loaded {df.count()} rows, {len(df.columns)} columns from staging")

# %% [markdown]
# Writing Delta Table

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("emission.default.emissions_data_clean")

print("Notebook 2 done — Delta table emission.default.emissions_data_clean. Ready for dashboard.")

# %%
spark.sql("DESCRIBE emission.default.emissions_data_clean").show(60, truncate=False)
